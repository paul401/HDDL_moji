# %%
import pandas as pd
import tensorflow as tf
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, GRU, concatenate
from keras.layers import Bidirectional, GlobalMaxPool1D, GlobalAveragePooling1D, GlobalMaxPooling1D
from keras.models import Model
from keras import initializers, regularizers, constraints, optimizers, layers
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
df_train = pd.read_csv("data/train.csv")
df_test  = pd.read_csv("data/test.csv")

# %%
texts_train = df_train["Comment"]
texts_test  = df_test["Comment"]
y_train = df_train["Insult"].values

# %%
maxlen = 50
vocab_size = 1000
glove_path = "glove/glove.twitter.27B."
embed_dim = 50

# %%
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(list(texts_train))
tokenized_train = tokenizer.texts_to_sequences(texts_train)
tokenized_test = tokenizer.texts_to_sequences(texts_test)
X_train = pad_sequences(tokenized_train, maxlen=maxlen)
X_test = pad_sequences(tokenized_test, maxlen=maxlen)

# %%
def get_coefs(word,*arr): 
    return word, np.asarray(arr, dtype='float32')
embeddings_index = dict(get_coefs(*o.strip().split()) for o in open(glove_path+str(embed_dim)+'d.txt'))
all_embs = np.stack(embeddings_index.values())
emb_mean,emb_std = all_embs.mean(), all_embs.std()

# %%
word_index = tokenizer.word_index
nb_words = min(vocab_size, len(word_index))
embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_dim))
for word, i in word_index.items():
    if i >= nb_words: continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector

# %%
# network

lstm_nodes = 32

inp = Input(shape = (maxlen,))
x = Embedding(nb_words, embed_dim, weights=[embedding_matrix])(inp)
x = Bidirectional(LSTM(lstm_nodes, return_sequences=True, dropout=0.1, recurrent_dropout=0.1))(x)
x = Bidirectional(LSTM(lstm_nodes, return_sequences=True, dropout=0.1, recurrent_dropout=0.1))(x)
x = GlobalMaxPool1D()(x)
x = Dense(1, activation = "sigmoid")(x)
model = Model(inputs=inp, outputs=x, name = "lstm")
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 50)                0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 50, 50)            50000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 50, 64)            21248
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 50, 64)            24832
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 96,145
# Trainable params: 96,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train,batch_size=16, epochs=20, verbose = 2, validation_split=0.1);
# Out:
# Train on 3552 samples, validate on 395 samples
# Epoch 1/20
#  - 20s - loss: 0.5446 - acc: 0.7416 - val_loss: 0.4489 - val_acc: 0.7899
# Epoch 2/20
#  - 18s - loss: 0.4047 - acc: 0.8201 - val_loss: 0.3748 - val_acc: 0.8481
# Epoch 3/20
#  - 18s - loss: 0.3547 - acc: 0.8502 - val_loss: 0.3729 - val_acc: 0.8456
# Epoch 4/20
#  - 19s - loss: 0.3310 - acc: 0.8590 - val_loss: 0.3636 - val_acc: 0.8430
# Epoch 5/20
#  - 22s - loss: 0.3088 - acc: 0.8719 - val_loss: 0.3827 - val_acc: 0.8354
# Epoch 6/20
#  - 23s - loss: 0.2924 - acc: 0.8801 - val_loss: 0.3762 - val_acc: 0.8456
# Epoch 7/20
#  - 21s - loss: 0.2764 - acc: 0.8818 - val_loss: 0.3813 - val_acc: 0.8481
# Epoch 8/20
#  - 21s - loss: 0.2692 - acc: 0.8953 - val_loss: 0.3724 - val_acc: 0.8481
# Epoch 9/20
#  - 22s - loss: 0.2507 - acc: 0.9026 - val_loss: 0.4557 - val_acc: 0.8076
# Epoch 10/20
#  - 23s - loss: 0.2326 - acc: 0.9048 - val_loss: 0.4172 - val_acc: 0.8430
# Epoch 11/20
#  - 22s - loss: 0.2188 - acc: 0.9113 - val_loss: 0.4206 - val_acc: 0.8430
# Epoch 12/20
#  - 21s - loss: 0.2055 - acc: 0.9184 - val_loss: 0.4287 - val_acc: 0.8506
# Epoch 13/20
#  - 21s - loss: 0.1904 - acc: 0.9262 - val_loss: 0.4333 - val_acc: 0.8557
# Epoch 14/20
#  - 21s - loss: 0.1759 - acc: 0.9307 - val_loss: 0.5504 - val_acc: 0.8228
# Epoch 15/20
#  - 21s - loss: 0.1597 - acc: 0.9364 - val_loss: 0.5437 - val_acc: 0.8354
# Epoch 16/20
#  - 21s - loss: 0.1483 - acc: 0.9412 - val_loss: 0.4876 - val_acc: 0.8354
# Epoch 17/20
#  - 21s - loss: 0.1389 - acc: 0.9462 - val_loss: 0.5596 - val_acc: 0.8304
# Epoch 18/20
#  - 21s - loss: 0.1199 - acc: 0.9541 - val_loss: 0.6610 - val_acc: 0.8278
# Epoch 19/20
#  - 21s - loss: 0.1165 - acc: 0.9519 - val_loss: 0.6529 - val_acc: 0.8253
# Epoch 20/20
#  - 21s - loss: 0.1085 - acc: 0.9597 - val_loss: 0.6346 - val_acc: 0.8405

# %%
y_predict = model.predict([X_test], batch_size=1024, verbose=1)
# Out:
# 2235/2235 [==============================] - 1s 505us/step

# %%
y_pred = np.zeros_like(y_predict)
y_pred[y_predict > 0.5] = 1

# %%
df_test["Insult"] = y_pred
df_test
# Out:
#         id             Date  \
# 0        1  20120603163526Z
# 1        2  20120531215447Z
# 2        3  20120823164228Z
# 3        4  20120826010752Z
# 4        5  20120602223825Z
# 5        6  20120603202442Z
# 6        7  20120603163604Z
# 7        8  20120602223902Z
# 8        9  20120528064125Z
# 9       10  20120603071243Z
# 10      11  20120531222107Z
# 11      12  20120602124231Z
# 12      13  20120531213632Z
# 13      14  20120826163900Z
# 14      15  20120824113742Z
# 15      16  20120528193938Z
# 16      17  20120602093617Z
# 17      18  20120531011755Z
# 18      19  20120603034157Z
# 19      20  20120528204217Z
# 20      21  20120531032438Z
# 21      22  20120602003811Z
# 22      23  20120528234413Z
# 23      24  20120823151417Z
# 24      25  20120531043929Z
# 25      26  20120531185334Z
# 26      27  20120531045417Z
# 27      28  20120531044152Z
# 28      29  20120531032755Z
# 29      30  20120603174414Z
# ...    ...              ...
# 2205  2206  20120603121617Z
# 2206  2207  20120603183745Z
# 2207  2208  20120531222116Z
# 2208  2209  20120601203721Z
# 2209  2210  20120531222046Z
# 2210  2211  20120529030109Z
# 2211  2212  20120528225243Z
# 2212  2213  20120602162000Z
# 2213  2214  20120528171624Z
# 2214  2215  20120603113409Z
# 2215  2216  20120527070000Z
# 2216  2217  20120601002438Z
# 2217  2218  20120823180303Z
# 2218  2219  20120527175414Z
# 2219  2220  20120602135012Z
# 2220  2221  20120602030455Z
# 2221  2222  20120602033400Z
# 2222  2223  20120531215533Z
# 2223  2224  20120529011159Z
# 2224  2225  20120603032103Z
# 2225  2226  20120601045826Z
# 2226  2227  20120826175454Z
# 2227  2228  20120528222848Z
# 2228  2229  20120527030950Z
# 2229  2230  20120825233538Z
# 2230  2231  20120528100303Z
# 2231  2232  20120531185813Z
# 2232  2233  20120529130822Z
# 2233  2234  20120531045826Z
# 2234  2235  20120531184524Z
#
#                                                 Comment  Insult
# 0                    "like this if you are a tribe fan"     0.0
# 1                 "you're idiot......................."     1.0
# 2     "I am a woman Babs, and the only "war on women...     0.0
# 3     "WOW & YOU BENEFITTED SO MANY WINS THIS YEAR F...     1.0
# 4     "haha green me red you now loser whos winning ...     1.0
# 5     "\nMe and God both hate-faggots.\n\nWhat's the...     0.0
# 6     "Oh go kiss the ass of a goat....and you DUMMY...     0.0
# 7                     "Not a chance Kid, you're wrong."     0.0
# 8               "On Some real Shit FUck LIVE JASMIN!!!"     0.0
# 9     "ok but where the hell was it released?you all...     0.0
# 10    "\xa0@CrankyVince has found our slice of the I...     0.0
# 11         "\xa0HAHAHAHAH, you are a delusional moron."     1.0
# 12    "There you are, been missing you.  How are you...     0.0
# 13    "wenttoau\n\nHe made a prediction just like yo...     0.0
# 14    "KATHY LEE....SHUT YOUR PIE HOLE...AND WHATS W...     1.0
# 15                                    "You're a crank."     1.0
# 16                      "Come on oppa you're a man. XD"     1.0
# 17    "I like your enthusiasm and initiative. You're...     0.0
# 18                      "Juggalo you suck at trolling "     0.0
# 19    "you seem a very eloquent, grounded and educat...     0.0
# 20    "Its a wild wild world, keep your dirty finger...     1.0
# 21              "Are you about to recapture your swag?"     0.0
# 22              "no shit.. you must be a\xa0genius\xa0"     1.0
# 23    "N\xe3o tenho a m\xednima paci\xeancia pra ess...     0.0
# 24                       "are you on 'roids by chance?"     0.0
# 25               "\xa0You are a disgusting human being"     1.0
# 26    "you are well versed when it may be on. \xa0Mu...     0.0
# 27             "we?  you and the mouse in your pocket?"     0.0
# 28              "glad you realize this :P\n\nkidding. "     0.0
# 29                 "Damn! You would rock this so hard!"     0.0
# ...                                                 ...     ...
# 2205                            "You may be right.\xa0"     0.0
# 2206                   "You're just like Mitt Flopney."     0.0
# 2207                                  "you sound queer"     1.0
# 2208                  "Was your funny boner active? ) "     0.0
# 2209  "most of those articles are about your tattoo ...     0.0
# 2210  "My favorite pre release hype is twilight prin...     0.0
# 2211  "\xa0@dawnofhero\xa0\n\xa0\nGo back to playing...     0.0
# 2212      "are you rooted or have unlocked bootloader?"     0.0
# 2213  "Loosing in the finals has to get you at least...     0.0
# 2214  "Yea, you guessed it right. I work at Microsof...     1.0
# 2215  "Who gives a fuck if it's a rental or not let ...     0.0
# 2216  "Yes, you are. You don't need to point it out,...     0.0
# 2217  "You're an idiot AND a spammer.\n\nIt's like i...     1.0
# 2218  "You know what got thousands k illed it was Sa...     0.0
# 2219  "I am a MM Fan but he was rather unfair to mos...     0.0
# 2220  "When you are ready for this.  Let me know.  I...     0.0
# 2221  "MENSAJE A PERIODICUCHOS INGLESES Y GRINGOS: F...     1.0
# 2222  "_FUCK_YOU_NIGGER_LOVING_FAGGOT_GO_SWING_IN_TH...     1.0
# 2223                                 "you are boring\n"     0.0
# 2224                                 "By your comment."     0.0
# 2225  "Fuck yOu Not working mother fucker!! Eat My D...     1.0
# 2226  "Nkk68\n\nHAHAHAHAHAHAHAHAHA is that all you g...     0.0
# 2227                 "What a smug basket you are.\xa0 "     0.0
# 2228  "Hey, Nils, you are silent about Muslims killi...     0.0
# 2229  "\xa0You must have crack in your bong, as it a...     0.0
# 2230  "FUCKIN LAME COME ON WTF STOP FUCKING OVER MY ...     0.0
# 2231  "YOU SHUT YOUR IGNORANT PIE HOLE YOU LITTLE IN...     1.0
# 2232  "sweetie pie is looking very much like her cou...     0.0
# 2233  "ball4real where are you with your miami g-ayn...     0.0
# 2234  "Man....if you are a 3 point shooter, you must...     0.0
#
# [2235 rows x 4 columns]
